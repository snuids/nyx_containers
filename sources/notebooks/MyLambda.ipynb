# %%
#@LISTEN=/topic/AAA,/topic/BBB
def lambda1_test():
    global es,global_message
    print("test1")
    print(es.info())
    print(global_message)
def lambda1_test2():
    print("test2")
    lambda1_test()

# %%
#@INTERVAL=1m
def lambda2_test():
    global curconfig
    print("test")
    logger.info("test")
    logger.info("test")
    logger.info("test")
    logger.info("test")
    logger.info("test")
    logger.info("test")
    logger.info("test")
    print(curconfig)
